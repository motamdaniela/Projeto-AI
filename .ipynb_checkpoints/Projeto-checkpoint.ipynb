# %%
#imports

import numpy as np
import pandas as pd

# %%
df = pd.read_csv('covid19.csv')

# %% [markdown]
# # Get information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  object
#  3   PATIENT_TYPE          1048575 non-null  object
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               192706 non-null   float64
#  6   PNEUMONIA             1032572 non-null  float64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              521310 non-null   float64
#  9   DIABETES              1045237 non-null  float64
#  10  COPD                  1045572 non-null  float64
#  11  ASTHMA                1045596 non-null  float64
#  12  INMSUPR               1045171 non-null  float64
#  13  HIPERTENSION          1045471 non-null  float64
#  14  OTHER_DISEASE         1043530 non-null  float64
#  15  CARDIOVASCULAR        1045499 non-null  float64
#  16  OBESITY               1045543 non-null  float64
#  17  RENAL_CHRONIC         1045569 non-null  float64
#  18  TOBACCO               1045355 non-null  float64
#  19  CLASIFFICATION_FINAL  1048575 non-null  int64
#  20  ICU                   192543 non-null   float64
# dtypes: float64(14), int64(4), object(3)
# memory usage: 168.0+ MB

# %%
df.head()
# Out:
#    USMER  MEDICAL_UNIT     SEX     PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0      2             1  female    returned home  03/05/2020      NaN
# 1      2             1    male    returned home  03/06/2020      NaN
# 2      2             1    male  hospitalization  09/06/2020     1.00
# 3      2             1  female    returned home  12/06/2020      NaN
# 4      2             1    male    returned home  21/06/2020      NaN
#
#    PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  \
# 0       1.00   65      2.00      2.00  ...    2.00     2.00          1.00
# 1       1.00   72       NaN      2.00  ...    2.00     2.00          1.00
# 2       2.00   55       NaN      1.00  ...    2.00     2.00          2.00
# 3       2.00   53      2.00      2.00  ...    2.00     2.00          2.00
# 4       2.00   68       NaN      1.00  ...    2.00     2.00          1.00
#
#    OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  \
# 0           2.00            2.00     2.00           2.00     2.00
# 1           2.00            2.00     1.00           1.00     2.00
# 2           2.00            2.00     2.00           2.00     2.00
# 3           2.00            2.00     2.00           2.00     2.00
# 4           2.00            2.00     2.00           2.00     2.00
#
#    CLASIFFICATION_FINAL  ICU
# 0                     3  NaN
# 1                     5  NaN
# 2                     3 2.00
# 3                     7  NaN
# 4                     3  NaN
#
# [5 rows x 21 columns]

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df.describe(include='all')
# Out:
#             USMER  MEDICAL_UNIT      SEX   PATIENT_TYPE   DATE_DIED   INTUBED  \
# count  1048575.00    1048575.00  1048575        1048575     1048575 192706.00
# unique        NaN           NaN        2              2         401       NaN
# top           NaN           NaN   female  returned home  9999-99-99       NaN
# freq          NaN           NaN   525064         848544      971633       NaN
# mean         1.63          8.98      NaN            NaN         NaN      1.83
# std          0.48          3.72      NaN            NaN         NaN      0.38
# min          1.00          1.00      NaN            NaN         NaN      1.00
# 25%          1.00          4.00      NaN            NaN         NaN      2.00
# 50%          2.00         12.00      NaN            NaN         NaN      2.00
# 75%          2.00         12.00      NaN            NaN         NaN      2.00
# max          2.00         13.00      NaN            NaN         NaN      2.00
#
#         PNEUMONIA        AGE  PREGNANT   DIABETES  ...     ASTHMA    INMSUPR  \
# count  1032572.00 1048575.00 521310.00 1045237.00  ... 1045596.00 1045171.00
# unique        NaN        NaN       NaN        NaN  ...        NaN        NaN
# top           NaN        NaN       NaN        NaN  ...        NaN        NaN
# freq          NaN        NaN       NaN        NaN  ...        NaN        NaN
# mean         1.86      41.79      1.98       1.88  ...       1.97       1.99
# std          0.34      16.91      0.12       0.32  ...       0.17       0.12
# min          1.00       0.00      1.00       1.00  ...       1.00       1.00
# 25%          2.00      30.00      2.00       2.00  ...       2.00       2.00
# 50%          2.00      40.00      2.00       2.00  ...       2.00       2.00
# 75%          2.00      53.00      2.00       2.00  ...       2.00       2.00
# max          2.00     121.00      2.00       2.00  ...       2.00       2.00
#
#         HIPERTENSION  OTHER_DISEASE  CARDIOVASCULAR    OBESITY  RENAL_CHRONIC  \
# count     1045471.00     1043530.00      1045499.00 1045543.00     1045569.00
# unique           NaN            NaN             NaN        NaN            NaN
# top              NaN            NaN             NaN        NaN            NaN
# freq             NaN            NaN             NaN        NaN            NaN
# mean            1.84           1.97            1.98       1.85           1.98
# std             0.36           0.16            0.14       0.36           0.13
# min             1.00           1.00            1.00       1.00           1.00
# 25%             2.00           2.00            2.00       2.00           2.00
# 50%             2.00           2.00            2.00       2.00           2.00
# 75%             2.00           2.00            2.00       2.00           2.00
# max             2.00           2.00            2.00       2.00           2.00
#
#           TOBACCO  CLASIFFICATION_FINAL       ICU
# count  1045355.00            1048575.00 192543.00
# unique        NaN                   NaN       NaN
# top           NaN                   NaN       NaN
# freq          NaN                   NaN       NaN
# mean         1.92                  5.31      1.91
# std          0.27                  1.88      0.28
# min          1.00                  1.00      1.00
# 25%          2.00                  3.00      2.00
# 50%          2.00                  6.00      2.00
# 75%          2.00                  7.00      2.00
# max          2.00                  7.00      2.00
#
# [11 rows x 21 columns]

# %%
df.dtypes
# Out:
# USMER                     int64
# MEDICAL_UNIT              int64
# SEX                      object
# PATIENT_TYPE             object
# DATE_DIED                object
# INTUBED                 float64
# PNEUMONIA               float64
# AGE                       int64
# PREGNANT                float64
# DIABETES                float64
# COPD                    float64
# ASTHMA                  float64
# INMSUPR                 float64
# HIPERTENSION            float64
# OTHER_DISEASE           float64
# CARDIOVASCULAR          float64
# OBESITY                 float64
# RENAL_CHRONIC           float64
# TOBACCO                 float64
# CLASIFFICATION_FINAL      int64
# ICU                     float64
# dtype: object

# %%
df.columns
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'DATE_DIED', 'INTUBED',
#        'PNEUMONIA', 'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
#        'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
#        'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# USMER                        0
# MEDICAL_UNIT                 0
# SEX                          0
# PATIENT_TYPE                 0
# DATE_DIED                    0
# INTUBED                 855869
# PNEUMONIA                16003
# AGE                          0
# PREGNANT                527265
# DIABETES                  3338
# COPD                      3003
# ASTHMA                    2979
# INMSUPR                   3404
# HIPERTENSION              3104
# OTHER_DISEASE             5045
# CARDIOVASCULAR            3076
# OBESITY                   3032
# RENAL_CHRONIC             3006
# TOBACCO                   3220
# CLASIFFICATION_FINAL         0
# ICU                     856032
# dtype: int64

# %%
df['DATE_DIED'].value_counts()
# Out:
# 9999-99-99    971633
# 06/07/2020      1000
# 07/07/2020       996
# 13/07/2020       990
# 16/06/2020       979
#                ...
# 24/11/2020         1
# 17/12/2020         1
# 08/12/2020         1
# 16/03/2021         1
# 22/04/2021         1
# Name: DATE_DIED, Length: 401, dtype: int64

# %% [markdown]
# ## analyse information

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score

import seaborn as sns
from scipy import stats

import matplotlib.pyplot as plt

# %%
sns.displot(df['AGE'].dropna(), bins = range(0,122,1),kde=True)
plt.show()

# %% [markdown]
# #### the majority or people are in the 20-40 age range

# %%
df.head(15)
# Out:
#     USMER  MEDICAL_UNIT     SEX     PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0       2             1  female    returned home  03/05/2020      NaN
# 1       2             1    male    returned home  03/06/2020      NaN
# 2       2             1    male  hospitalization  09/06/2020     1.00
# 3       2             1  female    returned home  12/06/2020      NaN
# 4       2             1    male    returned home  21/06/2020      NaN
# 5       2             1  female  hospitalization  9999-99-99     2.00
# 6       2             1  female    returned home  9999-99-99      NaN
# 7       2             1  female    returned home  9999-99-99      NaN
# 8       2             1  female  hospitalization  9999-99-99     2.00
# 9       2             1  female  hospitalization  9999-99-99     2.00
# 10      2             1  female    returned home  9999-99-99      NaN
# 11      2             1    male  hospitalization  9999-99-99     2.00
# 12      2             1    male  hospitalization  9999-99-99     2.00
# 13      2             1    male    returned home  9999-99-99      NaN
# 14      2             1  female    returned home  9999-99-99      NaN
#
#     PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  \
# 0        1.00   65      2.00      2.00  ...    2.00     2.00          1.00
# 1        1.00   72       NaN      2.00  ...    2.00     2.00          1.00
# 2        2.00   55       NaN      1.00  ...    2.00     2.00          2.00
# 3        2.00   53      2.00      2.00  ...    2.00     2.00          2.00
# 4        2.00   68       NaN      1.00  ...    2.00     2.00          1.00
# 5        1.00   40      2.00      2.00  ...    2.00     2.00          2.00
# 6        2.00   64      2.00      2.00  ...    2.00     2.00          2.00
# 7        1.00   64      2.00      1.00  ...    2.00     1.00          1.00
# 8        2.00   37      2.00      1.00  ...    2.00     2.00          1.00
# 9        2.00   25      2.00      2.00  ...    2.00     2.00          2.00
# 10       2.00   38      2.00      2.00  ...    2.00     2.00          2.00
# 11       2.00   24       NaN      2.00  ...    2.00     2.00          2.00
# 12       2.00   30       NaN      2.00  ...    2.00     2.00          2.00
# 13       2.00   55       NaN      2.00  ...    2.00     2.00          2.00
# 14       2.00   48      2.00      1.00  ...    2.00     2.00          2.00
#
#     OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  \
# 0            2.00            2.00     2.00           2.00     2.00
# 1            2.00            2.00     1.00           1.00     2.00
# 2            2.00            2.00     2.00           2.00     2.00
# 3            2.00            2.00     2.00           2.00     2.00
# 4            2.00            2.00     2.00           2.00     2.00
# 5            2.00            2.00     2.00           2.00     2.00
# 6            2.00            2.00     2.00           2.00     2.00
# 7            2.00            2.00     2.00           1.00     2.00
# 8            2.00            2.00     1.00           2.00     2.00
# 9            2.00            2.00     2.00           2.00     2.00
# 10           2.00            2.00     2.00           2.00     2.00
# 11           2.00            2.00     2.00           2.00     2.00
# 12           2.00            2.00     2.00           2.00     2.00
# 13           2.00            2.00     2.00           2.00     2.00
# 14           2.00            2.00     2.00           2.00     2.00
#
#     CLASIFFICATION_FINAL  ICU
# 0                      3  NaN
# 1                      5  NaN
# 2                      3 2.00
# 3                      7  NaN
# 4                      3  NaN
# 5                      3 2.00
# 6                      3  NaN
# 7                      3  NaN
# 8                      3 2.00
# 9                      3 2.00
# 10                     3  NaN
# 11                     3 2.00
# 12                     3 2.00
# 13                     3  NaN
# 14                     3  NaN
#
# [15 rows x 21 columns]

# %% [markdown]
# ## convert died dates to boolean

# %%
for index, value in df['DATE_DIED'].iteritems():
    if value == "9999-99-99":
        df.at[index, 'DIED'] = 0
    else:
        df.at[index, 'DIED'] = 1

# %%
df.head(10)
# Out:
#    USMER  MEDICAL_UNIT     SEX     PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0      2             1  female    returned home  03/05/2020      NaN
# 1      2             1    male    returned home  03/06/2020      NaN
# 2      2             1    male  hospitalization  09/06/2020     1.00
# 3      2             1  female    returned home  12/06/2020      NaN
# 4      2             1    male    returned home  21/06/2020      NaN
# 5      2             1  female  hospitalization  9999-99-99     2.00
# 6      2             1  female    returned home  9999-99-99      NaN
# 7      2             1  female    returned home  9999-99-99      NaN
# 8      2             1  female  hospitalization  9999-99-99     2.00
# 9      2             1  female  hospitalization  9999-99-99     2.00
#
#    PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# 0       1.00   65      2.00      2.00  ...     2.00          1.00
# 1       1.00   72       NaN      2.00  ...     2.00          1.00
# 2       2.00   55       NaN      1.00  ...     2.00          2.00
# 3       2.00   53      2.00      2.00  ...     2.00          2.00
# 4       2.00   68       NaN      1.00  ...     2.00          1.00
# 5       1.00   40      2.00      2.00  ...     2.00          2.00
# 6       2.00   64      2.00      2.00  ...     2.00          2.00
# 7       1.00   64      2.00      1.00  ...     1.00          1.00
# 8       2.00   37      2.00      1.00  ...     2.00          1.00
# 9       2.00   25      2.00      2.00  ...     2.00          2.00
#
#    OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  \
# 0           2.00            2.00     2.00           2.00     2.00
# 1           2.00            2.00     1.00           1.00     2.00
# 2           2.00            2.00     2.00           2.00     2.00
# 3           2.00            2.00     2.00           2.00     2.00
# 4           2.00            2.00     2.00           2.00     2.00
# 5           2.00            2.00     2.00           2.00     2.00
# 6           2.00            2.00     2.00           2.00     2.00
# 7           2.00            2.00     2.00           1.00     2.00
# 8           2.00            2.00     1.00           2.00     2.00
# 9           2.00            2.00     2.00           2.00     2.00
#
#    CLASIFFICATION_FINAL  ICU  DIED
# 0                     3  NaN  1.00
# 1                     5  NaN  1.00
# 2                     3 2.00  1.00
# 3                     7  NaN  1.00
# 4                     3  NaN  1.00
# 5                     3 2.00  0.00
# 6                     3  NaN  0.00
# 7                     3  NaN  0.00
# 8                     3 2.00  0.00
# 9                     3 2.00  0.00
#
# [10 rows x 22 columns]

# %% [markdown]
# ## test and predict

# %%
import matplotlib.pyplot as plt
